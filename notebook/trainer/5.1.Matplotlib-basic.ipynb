# %% [markdown]
# ### Importing Matplotlib

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Setting Styles

# %%
plt.style.use('classic')

# https://matplotlib.org/3.1.1/gallery/style_sheets/style_sheets_reference.html

# %% [markdown]
# ### plot example

# %%
import numpy as np
x = np.linspace(0, 10, 100)

fig = plt.figure()
plt.plot(x, np.sin(x), '-')
plt.plot(x, np.cos(x), '--');

# %% [markdown]
# ### Saving Figures to File

# %%
fig.savefig('plot1.png')

# %%
# !ls plot1.png
# Out:
# plot1.png

# %%
# 이미지 불러오기
from IPython.display import Image
Image('plot1.png')

# %%
# 지원 파일 포멧
fig.canvas.get_supported_filetypes()
# Out:
# {'ps': 'Postscript',
#  'eps': 'Encapsulated Postscript',
#  'pdf': 'Portable Document Format',
#  'pgf': 'PGF code for LaTeX',
#  'png': 'Portable Network Graphics',
#  'raw': 'Raw RGBA bitmap',
#  'rgba': 'Raw RGBA bitmap',
#  'svg': 'Scalable Vector Graphics',
#  'svgz': 'Scalable Vector Graphics'}

# %%
fig.savefig('plot1.svg')
# !ls plot1.svg
# Out:
# plot1.svg

# %% [markdown]
# ## Plot interface

# %% [markdown]
# #### MATLAB-style Interface

# %%
plt.figure()  # create a plot figure

# create the first of two panels and set current axis
plt.subplot(2, 1, 1) # (rows, columns, panel number)
plt.plot(x, np.sin(x))

# create the second panel and set current axis
plt.subplot(2, 1, 2)
plt.plot(x, np.cos(x));

# %% [markdown]
# #### Object-oriented interface

# %%
# First create a grid of plots
# ax will be an array of two Axes objects
fig, ax = plt.subplots(2)

# Call plot() method on the appropriate object
ax[0].plot(x, np.sin(x))
ax[1].plot(x, np.cos(x));

# %% [markdown]
# ### 한글 처리

# %%
import numpy as np
x = np.linspace(0, 10, 100)

fig = plt.figure()
plt.plot(x, np.sin(x), '-')
plt.plot(x, np.cos(x), '--')
plt.title('한글 제목');
# Out:
# /Users/iwannab1/miniconda3/envs/edu/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 54620 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/iwannab1/miniconda3/envs/edu/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 44544 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/iwannab1/miniconda3/envs/edu/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 51228 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/iwannab1/miniconda3/envs/edu/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 47785 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/iwannab1/miniconda3/envs/edu/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 54620 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/iwannab1/miniconda3/envs/edu/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 44544 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/iwannab1/miniconda3/envs/edu/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 51228 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/iwannab1/miniconda3/envs/edu/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 47785 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# - 현재 설정된 font 확인

# %%
plt.rcParams['font.family']
# Out:
# ['sans-serif']

# %% [markdown]
# - 사용가능한 한글 폰트 확인

# %%
import matplotlib.font_manager as fm

# windows
font_list = fm.findSystemFonts(fontpaths=None, fontext='ttf')

# OSX
#font_list_mac = fm.OSXInstalledFonts()

[(f.name, f.fname) for f in fm.fontManager.ttflist if 'Nanum' in f.name]
# Out:
# [('NanumBarunpen', '/Library/Fonts/NanumBarunpenRegular.ttf'),
#  ('NanumMyeongjo', '/Library/Fonts/NanumMyeongjo.ttf'),
#  ('NanumBarunGothic', '/Library/Fonts/NanumBarunGothic.ttf'),
#  ('NanumBarunGothic', '/Library/Fonts/NanumBarunGothicLight.ttf'),
#  ('NanumMyeongjo', '/Library/Fonts/NanumMyeongjoBold.ttf'),
#  ('NanumSquare', '/Library/Fonts/NanumSquareLight.ttf'),
#  ('NanumBarunGothic', '/Library/Fonts/NanumBarunGothicBold.ttf'),
#  ('NanumGothic', '/Library/Fonts/NanumGothicLight.ttf'),
#  ('Nanum Gothic',
#   '/System/Library/Assets/com_apple_MobileAsset_Font5/5cacaa007b5810b9f023061183336403b9d5c20b.asset/AssetData/NanumGothic.ttc'),
#  ('NanumMyeongjo', '/Library/Fonts/NanumMyeongjoExtraBold.ttf'),
#  ('Nanum Brush Script',
#   '/System/Library/Assets/com_apple_MobileAsset_Font5/89398fcde72f2206bbc162797eeb609f3f61fbd8.asset/AssetData/NanumScript.ttc'),
#  ('NanumGothic', '/Library/Fonts/NanumGothicBold.ttf'),
#  ('NanumSquare', '/Library/Fonts/NanumSquareBold.ttf'),
#  ('NanumBarunpen', '/Library/Fonts/NanumBarunpenBold.ttf'),
#  ('NanumSquare', '/Library/Fonts/NanumSquareExtraBold.ttf'),
#  ('Nanum Myeongjo',
#   '/System/Library/Assets/com_apple_MobileAsset_Font5/ee22bff5339ff376c79ca4c0814d49d3cfacb68e.asset/AssetData/NanumMyeongjo.ttc'),
#  ('NanumSquareRound', '/Library/Fonts/NanumSquareRoundL.ttf'),
#  ('Nanum Brush Script', '/Library/Fonts/NanumBrush.ttf'),
#  ('Nanum Pen Script', '/Library/Fonts/NanumPen.ttf'),
#  ('NanumBarunGothic', '/Library/Fonts/NanumBarunGothicUltraLight.ttf'),
#  ('NanumGothic', '/Library/Fonts/NanumGothicExtraBold.ttf'),
#  ('NanumGothic', '/Library/Fonts/NanumGothic.ttf'),
#  ('NanumSquareRound', '/Library/Fonts/NanumSquareRoundR.ttf')]

# %% [markdown]
# - 한글 지원 font로 변경

# %%
plt.rcParams["font.family"] = 'NanumGothic'
plt.rcParams["font.family"]
# Out:
# ['NanumGothic']

# %%
x = np.linspace(0, 10, 100)

fig = plt.figure()
plt.plot(x, np.sin(x), '-')
plt.plot(x, np.cos(x), '--')
plt.title('한글 제목');
# Out:
# /Users/iwannab1/miniconda3/envs/edu/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/iwannab1/miniconda3/envs/edu/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)
